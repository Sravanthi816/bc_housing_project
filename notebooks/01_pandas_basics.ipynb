# %%
import pandas as pd
df = pd.read_csv("../data/bc-data-catalogue-cma-2025-q4.csv")
df.head()
df.columns
df.info()
df.describe()
df.plot()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8550 entries, 0 to 8549
# Data columns (total 11 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   CMA ID                                 8550 non-null   int64
#  1   CMA NAME                               8550 non-null   object
#  2   YEAR                                   8550 non-null   int64
#  3   QUARTER                                8550 non-null   int64
#  4   HOUSING TYPE                           8550 non-null   object
#  5   MEDIAN HOUSING PRICE                   8550 non-null   float64
#  6   MEDIAN AFTER TAX ANNUAL FAMILY INCOME  8550 non-null   float64
#  7   PRIME INTEREST RATE                    8550 non-null   float64
#  8   MORTGAGE PAYMENT PERCENT INCOME        8550 non-null   float64
#  9   HISTORIC PAYMENT PERCENT INCOME        8550 non-null   float64
#  10  NUMBER OF RESALES                      8550 non-null   int64
# dtypes: float64(5), int64(4), object(2)
# memory usage: 734.9+ KB
# <Axes: >

# %%
df.columns = df.columns.str.lower().str.replace(" ", "_")
df.columns
# Out:
# Index(['cma_id', 'cma_name', 'year', 'quarter', 'housing_type',
#        'median_housing_price', 'median_after_tax_annual_family_income',
#        'prime_interest_rate', 'mortgage_payment_percent_income',
#        'historic_payment_percent_income', 'number_of_resales'],
#       dtype='object')

# %%
df["cma_name"]
df[[ "cma_name", "median_housing_price" ]]

df[df["cma_name"]=="Vancouver"]

df[df["median_housing_price"]>1000000]

df[(df["cma_name"]=="Vancouver")
& (df["median_housing_price"]>1000000)]
df[
    (df["cma_name"] == "Vancouver")
    |
    (df["cma_name"] == "Victoria")
]
df[
    df["cma_name"] == "Vancouver"
][
    ["cma_name", "median_housing_price"]
]
# Out:
#        cma_name  median_housing_price
# 47    Vancouver          2.400000e+05
# 48    Vancouver          1.600000e+05
# 49    Vancouver          2.890000e+05
# 50    Vancouver          2.057810e+05
# 108   Vancouver          2.446951e+05
# ...         ...                   ...
# 8446  Vancouver          9.727267e+05
# 8536  Vancouver          8.215124e+05
# 8537  Vancouver          6.576638e+05
# 8538  Vancouver          1.693809e+06
# 8539  Vancouver          9.461135e+05
#
# [416 rows x 2 columns]

# %%
df.sort_values(by='median_housing_price' , ascending= False)
# Out:
#       cma_id       cma_name  year  quarter    housing_type  \
# 8530     934       Squamish  2025        4  Detached Homes
# 8255     934       Squamish  2025        1  Detached Homes
# 7257     933      Vancouver  2022        2  Detached Homes
# 8437     934       Squamish  2025        3  Detached Homes
# 7351     933      Vancouver  2022        3  Detached Homes
# ...      ...            ...   ...      ...             ...
# 1160     950  Williams Lake  2004        1          Condos
# 811      905      Cranbrook  2003        1          Condos
# 2213     965        Terrace  2007        2          Condos
# 1790     952        Quesnel  2006        1          Condos
# 557      970  Prince George  2002        1          Condos
#
#       median_housing_price  median_after_tax_annual_family_income  \
# 8530          1.901596e+06                          130468.634035
# 8255          1.863092e+06                          125722.349748
# 7257          1.848202e+06                           90380.000000
# 8437          1.844805e+06                          128886.539273
# 7351          1.839257e+06                           90805.000000
# ...                    ...                                    ...
# 1160          4.826667e+04                           48455.000000
# 811           4.785556e+04                           46862.500000
# 2213          4.519231e+04                           57660.000000
# 1790          4.200000e+04                           54095.000000
# 557           2.960000e+04                           50475.000000
#
#       prime_interest_rate  mortgage_payment_percent_income  \
# 8530             4.546154                        84.731887
# 8255             5.257692                        92.665700
# 7257             3.276923                       104.240226
# 8437             4.930769                        86.710987
# 7351             4.719231                       120.149142
# ...                   ...                              ...
# 1160             4.192308                         6.127243
# 811              4.576923                         6.534963
# 2213             6.000000                         5.769204
# 1790             5.269231                         5.325260
# 557              3.788462                         3.457648
#
#       historic_payment_percent_income  number_of_resales
# 8530                        52.403669                 23
# 8255                        52.403669                 20
# 7257                        73.548082               4554
# 8437                        52.403669                 24
# 7351                        73.548082               3187
# ...                               ...                ...
# 1160                         7.269124                 15
# 811                         10.861144                 12
# 2213                         9.191911                 10
# 1790                         7.319197                 33
# 557                         12.338557                 27
#
# [8550 rows x 11 columns]

# %%
df.sort_values(by=["cma_name" ,"median_housing_price"], ascending =[True, False]).head(10)
df.sort_values(by = "median_housing_price" , ignore_index=True)
# Out:
#       cma_id       cma_name  year  quarter    housing_type  \
# 0        970  Prince George  2002        1          Condos
# 1        952        Quesnel  2006        1          Condos
# 2        965        Terrace  2007        2          Condos
# 3        905      Cranbrook  2003        1          Condos
# 4        950  Williams Lake  2004        1          Condos
# ...      ...            ...   ...      ...             ...
# 8545     933      Vancouver  2022        3  Detached Homes
# 8546     934       Squamish  2025        3  Detached Homes
# 8547     933      Vancouver  2022        2  Detached Homes
# 8548     934       Squamish  2025        1  Detached Homes
# 8549     934       Squamish  2025        4  Detached Homes
#
#       median_housing_price  median_after_tax_annual_family_income  \
# 0             2.960000e+04                           50475.000000
# 1             4.200000e+04                           54095.000000
# 2             4.519231e+04                           57660.000000
# 3             4.785556e+04                           46862.500000
# 4             4.826667e+04                           48455.000000
# ...                    ...                                    ...
# 8545          1.839257e+06                           90805.000000
# 8546          1.844805e+06                          128886.539273
# 8547          1.848202e+06                           90380.000000
# 8548          1.863092e+06                          125722.349748
# 8549          1.901596e+06                          130468.634035
#
#       prime_interest_rate  mortgage_payment_percent_income  \
# 0                3.788462                         3.457648
# 1                5.269231                         5.325260
# 2                6.000000                         5.769204
# 3                4.576923                         6.534963
# 4                4.192308                         6.127243
# ...                   ...                              ...
# 8545             4.719231                       120.149142
# 8546             4.930769                        86.710987
# 8547             3.276923                       104.240226
# 8548             5.257692                        92.665700
# 8549             4.546154                        84.731887
#
#       historic_payment_percent_income  number_of_resales
# 0                           12.338557                 27
# 1                            7.319197                 33
# 2                            9.191911                 10
# 3                           10.861144                 12
# 4                            7.269124                 15
# ...                               ...                ...
# 8545                        73.548082               3187
# 8546                        52.403669                 24
# 8547                        73.548082               4554
# 8548                        52.403669                 20
# 8549                        52.403669                 23
#
# [8550 rows x 11 columns]

# %%
df["median_housing_price"].mean()
df["median_housing_price"].max()
df["median_housing_price"].min()
df["median_housing_price"].sum()
df["median_housing_price"].count()
df["median_housing_price"].std()
df["median_housing_price"].var()
df.groupby("cma_name")["median_housing_price"].mean()
df.groupby("cma_name")["median_housing_price"].max()
df.groupby("cma_name")["median_housing_price"].min()
df.groupby("cma_name")["median_housing_price"].sum()
df.groupby("cma_name")["median_housing_price"].count()
df.groupby("cma_name")["median_housing_price"].agg(["mean", "max", "min", "sum", "count", "std", "var"])
# Out:
#                                mean           max            min  \
# cma_name
# Abbotsford - Mission  390626.770447  1.327447e+06   74405.909091
# Campbell River        308297.789853  7.613705e+05   75406.756757
# Chilliwack            349353.490619  1.061676e+06   58161.290323
# Courtenay             330724.165032  9.151378e+05   55495.000000
# Cranbrook             263336.683830  5.879954e+05   47855.555556
# Dawson Creek          222832.918182  3.750000e+05   72969.148936
# Duncan                321658.194479  8.338228e+05   59100.000000
# Fort St. John         284502.790019  4.509118e+05   67071.875000
# Kamloops              321261.815368  7.692530e+05   80868.421053
# Kelowna               408079.975785  1.088729e+06   91826.771654
# Ladysmith             787457.532835  9.156410e+05  432533.333333
# Nanaimo               338555.823230  8.875876e+05   88885.714286
# Nelson                535868.615874  7.771831e+05  272437.058824
# Parksville            400335.240760  9.196154e+05   78851.428571
# Penticton             334552.299914  8.558750e+05   78000.000000
# Port Alberni          254072.007449  5.912143e+05   52000.000000
# Powell River          302136.141403  7.204681e+05  108468.750000
# Prince George         244339.525163  5.346593e+05   29600.000000
# Prince Rupert         243847.124165  5.164684e+05   54900.000000
# Quesnel               209377.008329  4.210484e+05   42000.000000
# Salmon Arm            371855.276557  7.602011e+05   94147.058824
# Squamish              566623.676016  1.901596e+06  117153.846154
# Terrace               266899.924881  5.667151e+05   45192.307692
# Trail                 342803.880115  4.112581e+05  260367.126050
# Vancouver             584848.984412  1.848202e+06  150000.000000
# Vernon                326818.035430  8.389427e+05   65973.000000
# Victoria              475020.582286  1.268302e+06  122377.581121
# Williams Lake         237656.268052  5.038531e+05   48266.666667
#
#                                sum  count            std           var
# cma_name
# Abbotsford - Mission  1.625007e+08    416  247402.763022  6.120813e+10
# Campbell River        1.159200e+08    376  166296.577098  2.765455e+10
# Chilliwack            1.435843e+08    411  219261.340855  4.807554e+10
# Courtenay             1.336126e+08    404  196483.657866  3.860583e+10
# Cranbrook             7.689431e+07    292  122988.641115  1.512621e+10
# Dawson Creek          4.813191e+07    216   78271.313489  6.126399e+09
# Duncan                1.257684e+08    391  178299.029208  3.179054e+10
# Fort St. John         8.591984e+07    302   87979.643272  7.740418e+09
# Kamloops              1.326811e+08    413  157055.543866  2.466644e+10
# Kelowna               1.697613e+08    416  212569.549443  4.518581e+10
# Ladysmith             3.464813e+07     44  104061.460707  1.082879e+10
# Nanaimo               1.394850e+08    412  182614.620174  3.334810e+10
# Nelson                5.465860e+07    102  140650.904899  1.978268e+10
# Parksville            1.497254e+08    374  190699.114750  3.636615e+10
# Penticton             1.385047e+08    414  165545.171464  2.740520e+10
# Port Alberni          5.919878e+07    233  143480.065756  2.058653e+10
# Powell River          6.526141e+07    216  164117.714360  2.693462e+10
# Prince George         8.503015e+07    348  111826.097153  1.250508e+10
# Prince Rupert         4.901327e+07    201  123527.194772  1.525897e+10
# Quesnel               4.396917e+07    210   91525.345526  8.376889e+09
# Salmon Arm            1.004009e+08    270  149300.746493  2.229071e+10
# Squamish              2.005848e+08    354  361170.820479  1.304444e+11
# Terrace               5.791728e+07    217  132821.822532  1.764164e+10
# Trail                 1.371216e+07     40   37610.786003  1.414571e+09
# Vancouver             2.432972e+08    416  360502.235796  1.299619e+11
# Vernon                1.356295e+08    415  174800.786717  3.055532e+10
# Victoria              1.976086e+08    416  240719.527668  5.794589e+10
# Williams Lake         5.489860e+07    231  101544.196567  1.031122e+10

# %%
grouped_df = df.groupby("cma_name")["median_housing_price"].mean()
grouped_df.reset_index()
df.groupby("cma_name")["median_housing_price"].mean()\
.sort_values(ascending=False)\
.head(5).reset_index()
grouped_df = df.groupby("cma_name")["median_housing_price"].mean().reset_index()
result=grouped_df[grouped_df["median_housing_price"]>100000].head(10)
print(result)


grouped_df = df.groupby("cma_name")["mortgage_payment_percent_income"].mean()
result = grouped_df[grouped_df > 35].head(10).reset_index()
result
# Out:
#                cma_name  median_housing_price
# 0  Abbotsford - Mission         390626.770447
# 1        Campbell River         308297.789853
# 2            Chilliwack         349353.490619
# 3             Courtenay         330724.165032
# 4             Cranbrook         263336.683830
# 5          Dawson Creek         222832.918182
# 6                Duncan         321658.194479
# 7         Fort St. John         284502.790019
# 8              Kamloops         321261.815368
# 9               Kelowna         408079.975785
#                cma_name  mortgage_payment_percent_income
# 0  Abbotsford - Mission                        35.638262
# 1               Kelowna                        35.014647
# 2             Ladysmith                        58.077398
# 3                Nelson                        40.784228
# 4            Parksville                        36.040090
# 5              Squamish                        38.994364
# 6             Vancouver                        49.097142
# 7              Victoria                        36.822666

# %%
df.groupby(["cma_name", "housing_type"])["median_housing_price"].mean().head(10).reset_index()

df.pivot_table(
    index="cma_name",
    columns="housing_type",
    values="median_housing_price",
    aggfunc="mean"
).isnull().sum()
df.pivot_table(
    index="cma_name",
    columns="housing_type",
    values="median_housing_price",
    aggfunc="sum"
).isnull().sum()
df.pivot_table(
    index="cma_name",
    columns="housing_type",
    values="median_housing_price",
    aggfunc="max"
).fillna(0)
# Out:
# housing_type          All Housing Types         Condos  Detached Homes  \
# cma_name
# Abbotsford - Mission       9.141926e+05  481394.316163    1.327447e+06
# Campbell River             6.884747e+05  483250.000000    7.613705e+05
# Chilliwack                 8.766010e+05  424900.000000    1.061676e+06
# Courtenay                  7.889632e+05  421014.492754    9.151378e+05
# Cranbrook                  5.428238e+05  254458.333333    5.879954e+05
# Dawson Creek               3.178033e+05       0.000000    3.181757e+05
# Duncan                     7.324230e+05  355121.428571    8.338228e+05
# Fort St. John              3.828760e+05  284200.000000    4.509118e+05
# Kamloops                   6.727654e+05  405735.991379    7.692530e+05
# Kelowna                    8.128540e+05  541430.637363    1.088729e+06
# Ladysmith                  8.611650e+05       0.000000    9.156410e+05
# Nanaimo                    7.769441e+05  458510.810811    8.875876e+05
# Nelson                     7.557732e+05  518500.000000    7.771831e+05
# Parksville                 8.496050e+05  616562.500000    9.196154e+05
# Penticton                  6.518524e+05  481091.923077    8.558750e+05
# Port Alberni               5.875676e+05       0.000000    5.912143e+05
# Powell River               7.114331e+05  358240.000000    7.204681e+05
# Prince George              5.100000e+05  338099.368421    5.346593e+05
# Prince Rupert              4.997945e+05   72418.604651    5.164684e+05
# Quesnel                    4.194390e+05  104222.222222    4.210484e+05
# Salmon Arm                 6.750000e+05  354250.000000    7.602011e+05
# Squamish                   1.091465e+06  722536.082474    1.901596e+06
# Terrace                    5.520962e+05  166086.956522    5.667151e+05
# Trail                      4.112581e+05       0.000000    4.067917e+05
# Vancouver                  8.936258e+05  679625.551394    1.848202e+06
# Vernon                     6.968293e+05  332173.469388    8.389427e+05
# Victoria                   8.916852e+05  600663.337629    1.268302e+06
# Williams Lake              4.663891e+05  106519.230769    5.038531e+05
#
# housing_type             Row Homes
# cma_name
# Abbotsford - Mission  7.680342e+05
# Campbell River        5.964240e+05
# Chilliwack            7.186624e+05
# Courtenay             6.261786e+05
# Cranbrook             4.456280e+05
# Dawson Creek          3.750000e+05
# Duncan                5.975980e+05
# Fort St. John         3.521579e+05
# Kamloops              5.709926e+05
# Kelowna               7.170551e+05
# Ladysmith             5.859845e+05
# Nanaimo               6.258938e+05
# Nelson                6.503478e+05
# Parksville            7.469875e+05
# Penticton             6.134052e+05
# Port Alberni          4.633929e+05
# Powell River          3.747812e+05
# Prince George         4.177632e+05
# Prince Rupert         0.000000e+00
# Quesnel               0.000000e+00
# Salmon Arm            5.267778e+05
# Squamish              1.104350e+06
# Terrace               3.665000e+05
# Trail                 0.000000e+00
# Vancouver             1.006704e+06
# Vernon                5.906636e+05
# Victoria              8.227005e+05
# Williams Lake         2.638000e+05

# %%
avg_price_df =(df.groupby("cma_name")["median_housing_price"]
               .mean()
               .sort_values(ascending=True).
               head(10)
               )
avg_price_df.plot(kind="bar", 
                  figsize=(12,6),
                  xlabel="CMA Region", 
                  ylabel="Average Median Housing Price",
                  rot=45,grid=True,
                  color="blue",
                  title="Average Median Housing Price by CMA")
df.plot(kind="scatter", 
        x="median_housing_price", 
        y="mortgage_payment_percent_income",
        figsize=(12,6),
        rot=45,grid=True,
        color="blue",
        title="Average Median Housing Price by CMA")
vancouver_df = df[df["cma_name"] =="Vancouver"]
vancouver_trend = (
    vancouver_df.groupby("year")["median_housing_price"].mean()
)
vancouver_trend.plot(kind="line",
                     figsize=(12,6),
                     xlabel="Year",
                     ylabel="Average Median Housing Price",
                     rot=45,grid=True,
                     color="blue",
                     title="Average Median Housing Price Trend in Vancouver")
# Out:
# <Axes: title={'center': 'Average Median Housing Price Trend in Vancouver'}, xlabel='Year', ylabel='Average Median Housing Price'>

# %%
compare_df = df[(df["cma_name"]=="Vancouver") | 
                (df["cma_name"]=="Victoria")]

trend_df = compare_df.pivot_table(
    index="year",
    columns="cma_name",
    values="median_housing_price",
    aggfunc="mean"
)
trend_df.plot(kind="line",
            figsize=(12,6),
            xlabel="Year",
            ylabel="Average Median Housing Price",    
            rot=45,grid=True,
            color=["blue", "orange"],
            title="Vancouver vs Victoria Housing Trends")
# Out:
# <Axes: title={'center': 'Vancouver vs Victoria Housing Trends'}, xlabel='Year', ylabel='Average Median Housing Price'>
